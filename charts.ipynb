# %%
data = {
    'Cairo': {
        'venue': 20000,
        'setup': 30000,
        'transport': 1000,
        'total spent': 24000,
        'revenue': 40000,
        'profit': 16000
    },
    'Lagos': {
        'venue': 3500,
        'setup': 2000,
        'transport': 2500,
        'total spent': 8000,
        'revenue': 24000,
        'profit': 16000
    },
    'Johannesburg': {
        'venue': 20000,
        'setup': 3000,
        'transport': 2500,
        'total spent': 25500,
        'revenue': 41600,
        'profit': 16100
    }
}

# %%
import matplotlib.pyplot as plt
cities = data.keys()
total_spent = [data[city]['total spent'] for city in cities]
revenue = [data[city]['revenue'] for city in cities]
profit = [data[city]['profit'] for city in cities]

# Plotting the data
plt.figure(figsize=(10, 6))
plt.bar(cities, total_spent, label='Total Spent')
plt.bar(cities, revenue, label='Revenue')
plt.bar(cities, profit, label='Profit')

# Adding labels and title
plt.xlabel('City')
plt.ylabel('Amount (€)')
plt.title('Financial Summary by City')
plt.legend()

# Display the chart
plt.show()

# %%
cities = data.keys()
revenue = [data[city]['revenue'] for city in cities]
profit = [data[city]['profit'] for city in cities]

# Plotting the data
plt.figure(figsize=(10, 6))
plt.plot(cities, revenue, marker='o', label='Revenue')
plt.plot(cities, profit, marker='o', label='Profit')

# Adding labels and title
plt.xlabel('City')
plt.ylabel('Amount (€)')
plt.title('Profit and Revenue Comparison by City')
plt.legend()

# Display the chart
plt.show()

# %%
import numpy as np
# Extract the cities and corresponding data
cities = data.keys()
total_spent = [data[city]['total spent'] for city in cities]
revenue = [data[city]['revenue'] for city in cities]
profit = [data[city]['profit'] for city in cities]

# Plotting the data
fig, ax = plt.subplots(figsize=(10, 6))
bar_width = 0.35
index = np.arange(len(cities))

p1 = ax.bar(index, total_spent, bar_width, label='Total Spent')
p2 = ax.bar(index, revenue, bar_width, bottom=total_spent, label='Revenue')
p3 = ax.bar(index, profit, bar_width, bottom=np.array(total_spent) + np.array(revenue), label='Profit')

# Adding labels and title
ax.set_xlabel('City')
ax.set_ylabel('Amount (€)')
ax.set_title('Financial Breakdown by City')
ax.set_xticks(index)
ax.set_xticklabels(cities)
ax.legend()

# Display the chart
plt.show()

# %%
cities = data.keys()
total_spent = [data[city]['total spent'] for city in cities]
revenue = [data[city]['revenue'] for city in cities]
profit = [data[city]['profit'] for city in cities]

# Plotting the data
fig, ax = plt.subplots(figsize=(10, 6))
bar_width = 0.35
index = np.arange(len(cities))

p1 = ax.bar(index, total_spent, bar_width, label='Total Spent')
p2 = ax.bar(index, revenue, bar_width, bottom=total_spent, label='Revenue')
p3 = ax.bar(index, profit, bar_width, bottom=np.array(total_spent) + np.array(revenue), label='Profit')

# Adding labels and title
ax.set_xlabel('City')
ax.set_ylabel('Amount (€)')
ax.set_title('Financial Breakdown by City')
ax.set_xticks(index)
ax.set_xticklabels(cities)
ax.legend()

# Function to label each bar with its value
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate(f'{height}',
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),
                    textcoords="offset points",
                    ha='center', va='bottom')

# Add labels for each bar
autolabel(p1)
autolabel(p2)
autolabel(p3)

# Display the chart
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data
data = {
    'Cairo': {
        'venue': 20000,
        'setup': 30000,
        'transport': 1000,
        'total spent': 24000,
        'revenue': 40000,
        'profit': 16000
    },
    'Lagos': {
        'venue': 3500,
        'setup': 2000,
        'transport': 2500,
        'total spent': 8000,
        'revenue': 24000,
        'profit': 16000
    },
    'Johannesburg': {
        'venue': 20000,
        'setup': 3000,
        'transport': 2500,
        'total spent': 25500,
        'revenue': 41600,
        'profit': 16100
    }
}

# Extract the cities and corresponding data
cities = data.keys()
total_spent = [data[city]['total spent'] for city in cities]
revenue = [data[city]['revenue'] for city in cities]
profit = [data[city]['profit'] for city in cities]

# Plotting the data
fig, ax = plt.subplots(figsize=(10, 6))
bar_width = 0.35
index = np.arange(len(cities))

p1 = ax.bar(index, total_spent, bar_width, label='Total Spent')
p2 = ax.bar(index, revenue, bar_width, bottom=total_spent, label='Revenue')
p3 = ax.bar(index, profit, bar_width, bottom=np.array(total_spent) + np.array(revenue), label='Profit')

# Adding labels and title
ax.set_xlabel('City')
ax.set_ylabel('Amount (€)')
ax.set_title('Financial Breakdown by City')
ax.set_xticks(index)
ax.set_xticklabels(cities)
ax.legend()

# Function to label each bar with its value
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate(f'{height}',
                    xy=(rect.get_x() + rect.get_width() / 2, rect.get_y() + height / 2),
                    xytext=(0, 3),
                    textcoords="offset points",
                    ha='center', va='center')

# Add labels for each bar
autolabel(p1)
autolabel(p2)
autolabel(p3)

# Display the chart
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# Data
data = {
    'Cairo': {
        'venue': 20000,
        'setup': 30000,
        'transport': 1000,
        'total spent': 24000,
        'revenue': 40000,
        'profit': 16000
    },
    'Lagos': {
        'venue': 3500,
        'setup': 2000,
        'transport': 2500,
        'total spent': 8000,
        'revenue': 24000,
        'profit': 16000
    },
    'Johannesburg': {
        'venue': 20000,
        'setup': 3000,
        'transport': 2500,
        'total spent': 25500,
        'revenue': 41600,
        'profit': 16100
    }
}

# Extract the cities and corresponding data
cities = data.keys()
total_spent = [data[city]['total spent'] for city in cities]
revenue = [data[city]['revenue'] for city in cities]
profit = [data[city]['profit'] for city in cities]

# Plotting the data
fig, ax = plt.subplots(figsize=(10, 6))
bar_width = 0.35
index = np.arange(len(cities))

p1 = ax.bar(index, total_spent, bar_width, label='Total Spent')
p2 = ax.bar(index, revenue, bar_width, bottom=total_spent, label='Revenue')
p3 = ax.bar(index, profit, bar_width, bottom=np.array(total_spent) + np.array(revenue), label='Profit')

# Adding labels and title
ax.set_xlabel('City')
ax.set_ylabel('Amount (€)')
ax.set_title('Financial Breakdown by City')
ax.set_xticks(index)
ax.set_xticklabels(cities)
ax.legend()

# Load a bold font
prop = fm.FontProperties(weight='bold', size='larger')

# Function to label each bar with its value
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate(f'{format(height, ",")}€',
                    xy=(rect.get_x() + rect.get_width() / 2, rect.get_y() + height / 2),
                    xytext=(0, 3),
                    textcoords="offset points",
                    ha='center', va='center',
                    fontproperties=prop)

# Add labels for each bar
autolabel(p1)
autolabel(p2)
autolabel(p3)

# Display the chart
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# Data
data = {
    'Cairo': {
        'venue': 20000,
        'setup': 30000,
        'transport': 1000,
        'total spent': 24000,
        'revenue': 40000,
        'profit': 16000
    },
    'Lagos': {
        'venue': 3500,
        'setup': 2000,
        'transport': 2500,
        'total spent': 8000,
        'revenue': 24000,
        'profit': 16000
    },
    'Johannesburg': {
        'venue': 20000,
        'setup': 3000,
        'transport': 2500,
        'total spent': 25500,
        'revenue': 41600,
        'profit': 16100
    }
}

# Extract the cities and corresponding data
cities = data.keys()
total_spent = [data[city]['total spent'] for city in cities]
revenue = [data[city]['revenue'] for city in cities]
profit = [data[city]['profit'] for city in cities]

# Plotting the data
fig, ax = plt.subplots(figsize=(10, 6))
bar_width = 0.35
index = np.arange(len(cities))

p1 = ax.bar(index, total_spent, bar_width, label='Total Spent')
p2 = ax.bar(index, revenue, bar_width, bottom=total_spent, label='Revenue')
p3 = ax.bar(index, profit, bar_width, bottom=np.array(total_spent) + np.array(revenue), label='Profit')

# Adding labels and title
ax.set_xlabel('City')
ax.set_ylabel('Amount (€)')
ax.set_title('Financial Breakdown by City')

# Customize tick labels font properties
fontprops = fm.FontProperties(weight='bold', size='larger')
ax.set_xticks(index)
ax.set_xticklabels(cities, fontproperties=fontprops)  # Set the font properties for tick labels
ax.legend()

# Load a bold font
prop = fm.FontProperties(weight='bold', size='larger')

# Function to label each bar with its value
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate(f'{format(height, ",")}€',
                    xy=(rect.get_x() + rect.get_width() / 2, rect.get_y() + height / 2),
                    xytext=(0, 3),
                    textcoords="offset points",
                    ha='center', va='center',
                    fontproperties=prop)

# Add labels for each bar
autolabel(p1)
autolabel(p2)
autolabel(p3)

# Display the chart
plt.show()
